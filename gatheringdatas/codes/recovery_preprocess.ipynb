# %% [markdown]
# ## recovery 전처리 시작

# %%
# !pip install --user python-mecab-ko pyLDAvis

# %% [markdown]
# ### 쿠팡이랑 11번가 댓글 합치기

# %%
import pandas as pd

# %%
df_recover_coup=pd.read_csv('../datasets/recovery_coupang.csv')
df_recover_11st=pd.read_csv('../datasets/recovery_eleven.csv')

# %%
df_recovery_raw=pd.concat([df_recover_coup, df_recover_11st], axis=0)
df_recovery_raw
# Out:
#       Unnamed: 0                       _id  \
# 0              0  6512a329f82160e0ae9e7523
# 1              1  6512a329f82160e0ae9e7524
# 2              2  6512a329f82160e0ae9e7525
# 3              3  6512a329f82160e0ae9e7526
# 4              4  6512a329f82160e0ae9e7527
# ...          ...                       ...
# 7976        7976  65116a0e41ecef914dbd353a
# 7977        7977  65116a0e41ecef914dbd353b
# 7978        7978  65116a0e41ecef914dbd353c
# 7979        7979  65116a0e41ecef914dbd353d
# 7980        7980  65116a0e41ecef914dbd353e
#
#                                            product_name review_date  \
# 0     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.09.07
# 1     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.08.05
# 2     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.06.02
# 3     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.30
# 4     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.25
# ...                                                 ...         ...
# 7976              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 7977              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 7978              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 7979              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
# 7980              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.06
#
#                                          review_content  review_star  \
# 0     일주일 정도 먹은거 같은데 좋아요..피곤한 느낌이 많이 사라졌네요..\n맛은 뭐 그...          5.0
# 1                      복용한지 얼마되지않았지만 피로회복 활력증강에 좋은것 같아요          5.0
# 2     함량 높으면서도 품질 좋은 제품이라 믿고 구매했어요. 항상 체력적인 부분이 굉장히 ...          5.0
# 3     요즘 업무강도가 세져서 인지 집에만 오면 입맛도 없어 하고\n힘들어 하길래 구매해줬...          5.0
# 4     코로나 확진 이후 떨어진 컨디션이 쉽게 올라오질 않아서요. 블랙마카가 남자한테 특화...          5.0
# ...                                                 ...          ...
# 7976  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...          2.0
# 7977                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 7978     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요          5.0
# 7979                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0
# 7980                                                NaN          5.0
#
#              review_writer
# 0                     이*철
# 1                     김*운
# 2                     한*선
# 3                   노해바라기
# 4                     최*득
# ...                    ...
# 7976  macg****************
# 7977              rkdg****
# 7978                   채슨생
# 7979               smcd***
# 7980              pkks****
#
# [26161 rows x 7 columns]

# %%
df_recovery_raw.isnull().sum()
# Out:
# Unnamed: 0           0
# _id                  0
# product_name         9
# review_date          9
# review_content    4387
# review_star          9
# review_writer       10
# dtype: int64

# %%
df_recovery_raw=df_recovery_raw.dropna()

# %%
df_recovery_raw
# Out:
#       Unnamed: 0                       _id  \
# 0              0  6512a329f82160e0ae9e7523
# 1              1  6512a329f82160e0ae9e7524
# 2              2  6512a329f82160e0ae9e7525
# 3              3  6512a329f82160e0ae9e7526
# 4              4  6512a329f82160e0ae9e7527
# ...          ...                       ...
# 7975        7975  65116a0e41ecef914dbd3539
# 7976        7976  65116a0e41ecef914dbd353a
# 7977        7977  65116a0e41ecef914dbd353b
# 7978        7978  65116a0e41ecef914dbd353c
# 7979        7979  65116a0e41ecef914dbd353d
#
#                                            product_name review_date  \
# 0     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.09.07
# 1     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.08.05
# 2     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.06.02
# 3     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.30
# 4     [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.25
# ...                                                 ...         ...
# 7975              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 7976              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 7977              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 7978              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 7979              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                          review_content  review_star  \
# 0     일주일 정도 먹은거 같은데 좋아요..피곤한 느낌이 많이 사라졌네요..\n맛은 뭐 그...          5.0
# 1                      복용한지 얼마되지않았지만 피로회복 활력증강에 좋은것 같아요          5.0
# 2     함량 높으면서도 품질 좋은 제품이라 믿고 구매했어요. 항상 체력적인 부분이 굉장히 ...          5.0
# 3     요즘 업무강도가 세져서 인지 집에만 오면 입맛도 없어 하고\n힘들어 하길래 구매해줬...          5.0
# 4     코로나 확진 이후 떨어진 컨디션이 쉽게 올라오질 않아서요. 블랙마카가 남자한테 특화...          5.0
# ...                                                 ...          ...
# 7975  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...          2.0
# 7976  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...          2.0
# 7977                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 7978     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요          5.0
# 7979                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0
#
#              review_writer
# 0                     이*철
# 1                     김*운
# 2                     한*선
# 3                   노해바라기
# 4                     최*득
# ...                    ...
# 7975              rkdg****
# 7976  macg****************
# 7977              rkdg****
# 7978                   채슨생
# 7979               smcd***
#
# [21774 rows x 7 columns]

# %%
df_recovery_raw=df_recovery_raw.drop(columns=['Unnamed: 0','_id'])

# %%
df_recovery = df_recovery_raw.reset_index(drop=True)
df_recovery
# Out:
#                                             product_name review_date  \
# 0      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.09.07
# 1      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.08.05
# 2      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.06.02
# 3      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.30
# 4      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.25
# ...                                                  ...         ...
# 21769              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 21770              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 21771              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 21772              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 21773              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                           review_content  review_star  \
# 0      일주일 정도 먹은거 같은데 좋아요..피곤한 느낌이 많이 사라졌네요..\n맛은 뭐 그...          5.0
# 1                       복용한지 얼마되지않았지만 피로회복 활력증강에 좋은것 같아요          5.0
# 2      함량 높으면서도 품질 좋은 제품이라 믿고 구매했어요. 항상 체력적인 부분이 굉장히 ...          5.0
# 3      요즘 업무강도가 세져서 인지 집에만 오면 입맛도 없어 하고\n힘들어 하길래 구매해줬...          5.0
# 4      코로나 확진 이후 떨어진 컨디션이 쉽게 올라오질 않아서요. 블랙마카가 남자한테 특화...          5.0
# ...                                                  ...          ...
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...          2.0
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...          2.0
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요          5.0
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0
#
#               review_writer
# 0                      이*철
# 1                      김*운
# 2                      한*선
# 3                    노해바라기
# 4                      최*득
# ...                     ...
# 21769              rkdg****
# 21770  macg****************
# 21771              rkdg****
# 21772                   채슨생
# 21773               smcd***
#
# [21774 rows x 5 columns]

# %%
df_recovery.to_csv('../datasets/recovery.csv')

# %% [markdown]
# ### 불용어 처리 및 한글자 살리기 및 단어 치환,

# %%
# 대체어
df_replace = pd.read_excel('../datasets/sa_replace_list.xlsx')
df_replace[:5]
# Out:
#   before_replacement after_replacement
# 0                만졷ㄱ                만족
# 1               않좋아서              안좋아서
# 2               괜찮네요             보통이예요
# 3                시킬껭              시킬게요
# 4                  용                 요

# %%
# 불용어 
df_stop = pd.read_excel('../datasets/sa_stopword_list.xlsx')
df_stop[:5]
# Out:
#   stopword
# 0     가까스로
# 1       가량
# 2       가령
# 3       가민
# 4    가민커넥트

# %%
# 한글자 살리기
df_oneword=pd.read_excel('../datasets/sa_one_char_list.xlsx')
df_oneword[:5]
# Out:
#   one_char_keyword
# 0                컵
# 1                방
# 2                물
# 3                돈
# 4                꿈

# %%
## 단어 치환 함수 블로그 복사
def replace_word(review):
    for number in range(len(df_replace['before_replacement'])):
        try: 
            # 치환 단어만 데이터 치환
            if replace_list['before_replacement'][number] in review_content :
                review_content = review.replace(replace_list['before_replacement'][number], replace_list['after_replacement'][number])
        except: 
            pass
    return review

# %%
## 단어 치환 함수 블로그 복사
df_recovery['reveiw_replaced'] = ''
review_replaced_list = list()
for review in df_recovery['review_content']:
    review_replaced = replace_word(str(review))
    review_replaced_list.append(review_replaced)
df_recovery['reveiw_replaced'] = review_replaced_list
df_recovery[-10:]
# Out:
#                                 product_name review_date  \
# 21764  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.09.23
# 21765  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.03
# 21766  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.02.27
# 21767  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.02.27
# 21768  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.08.09
# 21769  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 21770  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 21771  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 21772  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 21773  푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                           review_content  review_star  \
# 21764  배송 빨라요 성능 보통이에요 유통기한 보통이에요\n제품 섭취한지 얼마되지않아.좋은지...          3.0
# 21765  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n아침마다 일어나는게 힘...          5.0
# 21766  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n요즘 들어 기력이 떨어...          5.0
# 21767  배송 빨라요 성능 성능이 뛰어나요 유통기한 보통이에요\n지금까지 먹어본것중 아르기닌...          5.0
# 21768                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...          2.0
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...          2.0
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요          5.0
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0
#
#                review_writer  \
# 21764             jong******
# 21765               daph****
# 21766  neti*****************
# 21767            with*******
# 21768                 jhi8**
# 21769               rkdg****
# 21770   macg****************
# 21771               rkdg****
# 21772                    채슨생
# 21773                smcd***
#
#                                          reveiw_replaced
# 21764  배송 빨라요 성능 보통이에요 유통기한 보통이에요\n제품 섭취한지 얼마되지않아.좋은지...
# 21765  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n아침마다 일어나는게 힘...
# 21766  배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요\n요즘 들어 기력이 떨어...
# 21767  배송 빨라요 성능 성능이 뛰어나요 유통기한 보통이에요\n지금까지 먹어본것중 아르기닌...
# 21768                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요

# %%
# 내용의 토큰화 먼저_healthapp 복사
from mecab import MeCab
mecab = MeCab()
stop=df_stop['stopword'].tolist()
oneword=df_oneword['one_char_keyword'].tolist()

# %%
tokenized_reviews = list()
# df_recovery['reveiw_replaced'] 열의 각 텍스트에 대해 토큰화 수행
for review_text in df_recovery['reveiw_replaced']:
    tokens = []
    try:
        for word in mecab.pos(review_text):
            token, pos = word[0], word[1]
            if len(token) > 1 or token in oneword:
                tokens.append(token)
    except:
        pass
    tokenized_reviews.append(tokens)

# %%
# 토큰화된 결과를 새로운 열 'tokenized_review'에 추가
df_recovery['tokenized_review'] = tokenized_reviews

# %%
df_recovery
# Out:
#                                             product_name review_date  \
# 0      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.09.07
# 1      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.08.05
# 2      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.06.02
# 3      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.30
# 4      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.25
# ...                                                  ...         ...
# 21769              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 21770              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 21771              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 21772              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 21773              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                           review_content  review_star  \
# 0      일주일 정도 먹은거 같은데 좋아요..피곤한 느낌이 많이 사라졌네요..\n맛은 뭐 그...          5.0
# 1                       복용한지 얼마되지않았지만 피로회복 활력증강에 좋은것 같아요          5.0
# 2      함량 높으면서도 품질 좋은 제품이라 믿고 구매했어요. 항상 체력적인 부분이 굉장히 ...          5.0
# 3      요즘 업무강도가 세져서 인지 집에만 오면 입맛도 없어 하고\n힘들어 하길래 구매해줬...          5.0
# 4      코로나 확진 이후 떨어진 컨디션이 쉽게 올라오질 않아서요. 블랙마카가 남자한테 특화...          5.0
# ...                                                  ...          ...
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...          2.0
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...          2.0
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요          5.0
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0
#
#               review_writer  \
# 0                      이*철
# 1                      김*운
# 2                      한*선
# 3                    노해바라기
# 4                      최*득
# ...                     ...
# 21769              rkdg****
# 21770  macg****************
# 21771              rkdg****
# 21772                   채슨생
# 21773               smcd***
#
#                                          reveiw_replaced  \
# 0      일주일 정도 먹은거 같은데 좋아요..피곤한 느낌이 많이 사라졌네요..\n맛은 뭐 그...
# 1                       복용한지 얼마되지않았지만 피로회복 활력증강에 좋은것 같아요
# 2      함량 높으면서도 품질 좋은 제품이라 믿고 구매했어요. 항상 체력적인 부분이 굉장히 ...
# 3      요즘 업무강도가 세져서 인지 집에만 오면 입맛도 없어 하고\n힘들어 하길래 구매해줬...
# 4      코로나 확진 이후 떨어진 컨디션이 쉽게 올라오질 않아서요. 블랙마카가 남자한테 특화...
# ...                                                  ...
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요
#
#                                         tokenized_review
# 0      [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 1                [복용, 한지, 얼마, 않, 지만, 피로, 회복, 활력, 증강, 아요]
# 2      [함량, 으면서, 품질, 제품, 구매, 어요, 항상, 체력, 부분, 굉장히, 힘들,...
# 3      [요즘, 업무, 강도, 져서, 인지, 입맛, 힘들, 길래, 구매, 어요, 성분, 함...
# 4      [코로나, 확진, 이후, 떨어진, 컨디션, 올라오, 않, 아서요, 블랙, 마카, 남...
# ...                                                  ...
# 21769  [배송, 빨라요, 성능, 성능, 별로, 예요, 유통, 기한, 기한, 넉넉, 해요, ...
# 21770  [배송, 빨라요, 성능, 성능, 별로, 예요, 유통, 기한, 보통, 에요, 호불호,...
# 21771         [배송, 빨라요, 성능, 성능, 뛰어나, 유통, 기한, 기한, 넉넉, 해요]
# 21772  [배송, 보통, 에요, 성능, 보통, 에요, 유통, 기한, 보통, 에요, 지인, 선...
# 21773          [배송, 보통, 에요, 성능, 성능, 뛰어나, 유통, 기한, 보통, 에요]
#
# [21774 rows x 7 columns]

# %%
# 불용어 제거 _ 블로그 복사_
possible_reviews = list()
def stopword(tokens) :
    for token in tokens: 
        if token not in stop:
            possible_reviews.append(token)
    return possible_reviews

# %%
df_recovery['possible_reviews']=df_recovery['tokenized_review'].apply(stopword)

# %%
df_recovery
# Out:
#                                             product_name review_date  \
# 0      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.09.07
# 1      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2023.08.05
# 2      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.06.02
# 3      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.30
# 4      [조아제약] 블랙마카 마스터클래스 아르기닌 야관문 흑마늘 활력강화, 60정, 810...  2022.05.25
# ...                                                  ...         ...
# 21769              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.15
# 21770              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.07.07
# 21771              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.06.16
# 21772              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.04.06
# 21773              푸드올로지 윤성빈PICK 에너지붐 /고함량 액상 아르기닌/ 피로회복  2022.03.27
#
#                                           review_content  review_star  \
# 0      일주일 정도 먹은거 같은데 좋아요..피곤한 느낌이 많이 사라졌네요..\n맛은 뭐 그...          5.0
# 1                       복용한지 얼마되지않았지만 피로회복 활력증강에 좋은것 같아요          5.0
# 2      함량 높으면서도 품질 좋은 제품이라 믿고 구매했어요. 항상 체력적인 부분이 굉장히 ...          5.0
# 3      요즘 업무강도가 세져서 인지 집에만 오면 입맛도 없어 하고\n힘들어 하길래 구매해줬...          5.0
# 4      코로나 확진 이후 떨어진 컨디션이 쉽게 올라오질 않아서요. 블랙마카가 남자한테 특화...          5.0
# ...                                                  ...          ...
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...          2.0
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...          2.0
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요          5.0
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요          5.0
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요          5.0
#
#               review_writer  \
# 0                      이*철
# 1                      김*운
# 2                      한*선
# 3                    노해바라기
# 4                      최*득
# ...                     ...
# 21769              rkdg****
# 21770  macg****************
# 21771              rkdg****
# 21772                   채슨생
# 21773               smcd***
#
#                                          reveiw_replaced  \
# 0      일주일 정도 먹은거 같은데 좋아요..피곤한 느낌이 많이 사라졌네요..\n맛은 뭐 그...
# 1                       복용한지 얼마되지않았지만 피로회복 활력증강에 좋은것 같아요
# 2      함량 높으면서도 품질 좋은 제품이라 믿고 구매했어요. 항상 체력적인 부분이 굉장히 ...
# 3      요즘 업무강도가 세져서 인지 집에만 오면 입맛도 없어 하고\n힘들어 하길래 구매해줬...
# 4      코로나 확진 이후 떨어진 컨디션이 쉽게 올라오질 않아서요. 블랙마카가 남자한테 특화...
# ...                                                  ...
# 21769  배송 빨라요 성능 성능이 별로예요 유통기한 기한이 넉넉해요\n2박스 먹어봤으나 피로...
# 21770  배송 빨라요 성능 성능이 별로예요 유통기한 보통이에요\n호불호가 있을지 모르겠지만 ...
# 21771                   배송 빨라요 성능 성능이 뛰어나요 유통기한 기한이 넉넉해요
# 21772     배송 보통이에요 성능 보통이에요 유통기한 보통이에요\n지인 선물을줬는데  좋아했어요
# 21773                    배송 보통이에요 성능 성능이 뛰어나요 유통기한 보통이에요
#
#                                         tokenized_review  \
# 0      [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 1                [복용, 한지, 얼마, 않, 지만, 피로, 회복, 활력, 증강, 아요]
# 2      [함량, 으면서, 품질, 제품, 구매, 어요, 항상, 체력, 부분, 굉장히, 힘들,...
# 3      [요즘, 업무, 강도, 져서, 인지, 입맛, 힘들, 길래, 구매, 어요, 성분, 함...
# 4      [코로나, 확진, 이후, 떨어진, 컨디션, 올라오, 않, 아서요, 블랙, 마카, 남...
# ...                                                  ...
# 21769  [배송, 빨라요, 성능, 성능, 별로, 예요, 유통, 기한, 기한, 넉넉, 해요, ...
# 21770  [배송, 빨라요, 성능, 성능, 별로, 예요, 유통, 기한, 보통, 에요, 호불호,...
# 21771         [배송, 빨라요, 성능, 성능, 뛰어나, 유통, 기한, 기한, 넉넉, 해요]
# 21772  [배송, 보통, 에요, 성능, 보통, 에요, 유통, 기한, 보통, 에요, 지인, 선...
# 21773          [배송, 보통, 에요, 성능, 성능, 뛰어나, 유통, 기한, 보통, 에요]
#
#                                         possible_reviews
# 0      [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 1      [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 2      [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 3      [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 4      [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# ...                                                  ...
# 21769  [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 21770  [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 21771  [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 21772  [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
# 21773  [주일, 정도, 아요, 피곤, 느낌, 많이, 사라졌, 네요, 그냥, 물, 함께, 삼...
#
# [21774 rows x 8 columns]
